# %%
with open('2.txt') as file: 
    ans = 0 
    for line in file:
        # for temp in structure:
        temp = [int(i) for i in line.split()]
        init_diff = temp[1] - temp[0]
        # print(f" initial diffence = {init_diff}")
        incr = True
        decr = True
        if init_diff > 0 and init_diff < 4: 
            #increasing
            for i in range(1, len(temp)-1):
                #print(f" Increasing branch - Val at i is: {temp[i+1]} and at i+1 is:{temp[i]} and  diff is: {temp[i+1]-temp[i]} something here")
                if temp[i+1]-temp[i] > 3 or temp[i+1]-temp[i] <= 0:
                    incr = False
            if incr == True:
                print(f"increasing {temp}")
                ans += 1
            # print("Safe increasing")
        elif init_diff < 0 and init_diff > -4:
            #decreasing
            for i in range(1, len(temp)-1):
                #print(f" Decreasing branch - Val at i is: {temp[i]} and at i+1 is:{temp[i+1]} and  diff is: {temp[i]-temp[i+1]} something here")
                if temp[i]-temp[i+1] > 3 or temp[i]-temp[i+1] <= 0:
                    decr = False
            # print("Safe decreasing")
            if decr == True:
                print(f"decreasing {temp}")
                ans += 1
        else:
            if init_diff >=1 and init_diff <= 3:
                print(init_diff)
            # print("Nope")
            # print(temp)
    print(ans)
# Out:
# decreasing [97, 95, 92, 90, 87, 85, 84]
# increasing [76, 77, 80, 83, 84, 87, 88, 90]
# decreasing [81, 80, 78, 77, 75, 74]
# decreasing [94, 93, 91, 89, 88, 86]
# decreasing [85, 82, 79, 76, 74, 73, 72, 71]
# decreasing [73, 71, 69, 66, 64, 63]
# increasing [17, 18, 21, 24, 26, 29, 30]
# increasing [72, 73, 76, 79, 82, 84]
# decreasing [16, 14, 11, 10, 9, 8, 6]
# increasing [25, 27, 30, 33, 35]
# increasing [30, 31, 34, 37, 39]
# increasing [82, 84, 87, 90, 93, 95]
# decreasing [21, 19, 16, 14, 13, 11, 9]
# increasing [43, 46, 49, 50, 52, 55, 57]
# decreasing [70, 69, 67, 66, 65, 63, 61, 60]
# decreasing [29, 26, 23, 22, 20, 17, 14]
# decreasing [74, 73, 71, 68, 66, 65, 64]
# decreasing [85, 83, 80, 79, 77, 76, 73, 71]
# increasing [10, 11, 14, 16, 17, 18, 20]
# decreasing [47, 44, 42, 39, 38, 35, 32, 30]
# increasing [67, 68, 70, 71, 74, 76, 77, 79]
# increasing [35, 37, 40, 43, 45, 46, 48, 51]
# decreasing [66, 64, 61, 58, 55, 53, 52, 49]
# increasing [76, 79, 80, 81, 82, 83, 86]
# decreasing [56, 54, 51, 49, 47]
# decreasing [67, 64, 63, 60, 58, 57, 54, 52]
# increasing [10, 12, 14, 16, 18, 21, 24]
# increasing [79, 82, 83, 84, 86, 87, 89, 90]
# decreasing [79, 76, 75, 74, 73, 70, 67]
# increasing [48, 51, 52, 53, 54, 57]
# decreasing [42, 41, 38, 35, 34, 32, 29, 28]
# increasing [2, 5, 6, 8, 10, 11, 14, 15]
# decreasing [77, 75, 73, 72, 69, 67]
# increasing [81, 84, 87, 90, 92, 93, 94]
# increasing [29, 32, 35, 36, 39, 42, 43, 44]
# decreasing [25, 24, 23, 20, 19, 17, 16]
# increasing [64, 67, 69, 70, 73, 74]
# increasing [17, 19, 20, 21, 22, 24, 25]
# increasing [42, 43, 44, 45, 48, 50, 52, 54]
# decreasing [45, 42, 41, 38, 37]
# decreasing [80, 78, 75, 72, 69, 66, 63, 62]
# increasing [8, 9, 11, 14, 15, 18, 20, 22]
# decreasing [52, 51, 50, 47, 44]
# decreasing [23, 20, 19, 18, 16, 15, 14]
# increasing [18, 21, 24, 25, 26]
# increasing [86, 88, 89, 91, 93, 94, 95, 97]
# increasing [5, 6, 9, 11, 14, 17, 18]
# decreasing [74, 73, 72, 71, 70, 68]
# increasing [70, 73, 75, 77, 80]
# increasing [56, 59, 60, 61, 62, 64, 67]
# increasing [21, 24, 26, 29, 32, 34, 35, 37]
# increasing [31, 34, 36, 37, 38]
# decreasing [18, 15, 13, 10, 8, 7, 4]
# increasing [36, 39, 42, 44, 45, 47]
# increasing [71, 74, 76, 77, 78, 79, 82]
# increasing [31, 34, 36, 38, 39, 42]
# increasing [20, 22, 23, 24, 26, 28, 29]
# decreasing [72, 71, 70, 67, 64, 62, 61, 58]
# increasing [71, 74, 75, 76, 77, 78, 80, 82]
# increasing [49, 50, 53, 56, 57, 58, 61]
# decreasing [15, 14, 13, 10, 7, 6, 3]
# decreasing [28, 26, 24, 21, 19, 16, 14]
# decreasing [50, 47, 46, 45, 43]
# decreasing [37, 36, 35, 32, 30]
# decreasing [71, 69, 66, 63, 62, 61, 60]
# increasing [62, 64, 66, 68, 69, 72, 74, 76]
# increasing [40, 41, 42, 45, 48, 50]
# decreasing [20, 17, 16, 15, 12, 11, 10]
# increasing [9, 10, 13, 15, 17, 20, 23, 24]
# increasing [38, 39, 42, 43, 44, 45]
# increasing [18, 19, 20, 23, 24, 27, 28, 29]
# increasing [5, 8, 9, 12, 14, 16, 17]
# decreasing [58, 55, 54, 53, 51, 49]
# increasing [15, 18, 21, 23, 25]
# decreasing [20, 19, 18, 16, 15, 13]
# decreasing [69, 67, 66, 63, 60, 58, 57]
# decreasing [64, 61, 60, 57, 54, 52, 50, 49]
# increasing [20, 22, 25, 26, 27, 28]
# increasing [42, 45, 48, 50, 52, 55, 57]
# decreasing [18, 17, 15, 13, 12, 10]
# decreasing [22, 19, 16, 15, 14, 11, 9]
# decreasing [67, 64, 61, 58, 55, 53, 51]
# increasing [50, 52, 53, 56, 59, 62, 65, 68]
# increasing [52, 55, 57, 58, 60, 62]
# decreasing [40, 38, 37, 35, 32, 31, 30]
# decreasing [69, 68, 66, 65, 63, 61, 58]
# decreasing [49, 48, 45, 42, 40, 37, 34]
# decreasing [37, 36, 34, 31, 28]
# increasing [52, 53, 56, 59, 60]
# increasing [39, 41, 42, 43, 45, 48, 51, 52]
# increasing [15, 16, 19, 22, 23]
# increasing [84, 86, 89, 91, 92, 95, 97, 99]
# increasing [83, 86, 88, 90, 92, 95]
# increasing [63, 64, 67, 68, 71]
# decreasing [90, 87, 85, 83, 82, 79]
# increasing [56, 58, 60, 62, 63, 64, 66, 69]
# decreasing [14, 12, 10, 9, 6]
# decreasing [43, 42, 41, 40, 37]
# decreasing [18, 16, 15, 14, 11]
# increasing [57, 58, 59, 61, 64, 66]
# decreasing [60, 59, 56, 55, 52, 49, 48]
# increasing [19, 21, 22, 23, 26, 29]
# decreasing [49, 47, 46, 43, 40]
# increasing [84, 85, 87, 89, 91, 94, 96]
# decreasing [61, 60, 58, 56, 53, 50, 47, 44]
# increasing [66, 67, 70, 73, 75, 78, 80, 81]
# decreasing [27, 25, 22, 19, 18, 15, 13, 10]
# increasing [44, 47, 48, 49, 52, 53, 54, 56]
# decreasing [17, 14, 11, 9, 6, 4]
# decreasing [94, 91, 88, 86, 85]
# decreasing [58, 57, 55, 52, 51]
# decreasing [90, 89, 87, 85, 84, 81, 80, 78]
# increasing [35, 37, 38, 41, 44, 45]
# increasing [38, 39, 40, 41, 43]
# increasing [89, 90, 92, 93, 94, 97, 98]
# decreasing [62, 59, 58, 55, 54, 52, 51, 49]
# increasing [9, 12, 14, 16, 17, 19, 22, 24]
# decreasing [94, 92, 89, 86, 85, 84, 81, 78]
# increasing [28, 30, 31, 34, 35, 36, 38, 41]
# increasing [59, 61, 64, 65, 66, 69, 70, 72]
# decreasing [77, 76, 75, 72, 71, 70, 68, 65]
# decreasing [55, 54, 52, 49, 48, 47, 44]
# decreasing [96, 94, 93, 92, 89]
# increasing [40, 41, 42, 45, 46, 48, 50, 53]
# increasing [52, 53, 54, 56, 58, 60, 62]
# decreasing [98, 97, 94, 92, 89, 88, 87, 86]
# increasing [68, 69, 72, 75, 77, 80]
# decreasing [49, 48, 47, 44, 41, 39, 36]
# decreasing [57, 56, 53, 51, 50, 48, 47]
# increasing [11, 14, 15, 17, 20, 23, 26, 28]
# decreasing [21, 19, 18, 16, 14]
# increasing [49, 51, 54, 57, 60, 63, 66, 69]
# decreasing [50, 47, 46, 44, 42, 41, 39]
# decreasing [45, 42, 41, 39, 36, 33, 32, 30]
# increasing [47, 48, 49, 52, 53, 55, 56]
# increasing [79, 80, 82, 83, 85, 86, 87, 90]
# decreasing [31, 28, 27, 26, 23]
# increasing [3, 6, 7, 10, 13]
# increasing [84, 85, 88, 91, 94, 95, 96]
# decreasing [59, 57, 55, 52, 50, 49]
# decreasing [55, 52, 49, 48, 45, 44]
# increasing [13, 14, 16, 18, 19, 20]
# increasing [70, 71, 74, 77, 78, 80, 83]
# increasing [36, 38, 39, 42, 45, 46, 49, 50]
# decreasing [95, 93, 90, 87, 86, 85, 83]
# increasing [14, 17, 20, 22, 25]
# decreasing [20, 18, 16, 15, 14, 13, 12, 9]
# increasing [32, 34, 35, 36, 39, 40, 41]
# increasing [31, 34, 36, 37, 39, 40, 43]
# decreasing [73, 72, 70, 67, 64]
# increasing [47, 48, 50, 53, 54]
# decreasing [91, 88, 85, 84, 83, 81, 79, 77]
# decreasing [49, 46, 44, 41, 39, 37, 36]
# decreasing [20, 19, 18, 17, 16, 15, 12]
# increasing [86, 88, 89, 92, 93, 96]
# increasing [78, 80, 81, 84, 87, 88, 90, 91]
# decreasing [22, 20, 19, 18, 16, 13]
# increasing [2, 3, 6, 7, 10, 11]
# decreasing [41, 38, 37, 34, 33, 30, 28]
# decreasing [28, 27, 24, 23, 21, 20, 17, 14]
# increasing [74, 77, 80, 81, 82, 84]
# decreasing [69, 67, 65, 64, 63, 62]
# decreasing [81, 79, 78, 76, 73, 72]
# decreasing [54, 53, 52, 50, 47]
# decreasing [17, 16, 15, 13, 11]
# increasing [57, 59, 60, 62, 64]
# increasing [23, 25, 27, 30, 32, 34]
# decreasing [29, 26, 25, 24, 23]
# decreasing [30, 28, 26, 25, 22, 19, 18]
# decreasing [70, 67, 64, 61, 58, 57]
# increasing [62, 64, 65, 68, 71]
# increasing [83, 86, 89, 92, 93, 94, 96, 99]
# decreasing [47, 45, 44, 43, 40, 37, 35, 34]
# increasing [47, 48, 49, 52, 55, 57, 59, 60]
# increasing [3, 4, 7, 10, 13, 15, 18]
# increasing [64, 66, 68, 69, 70, 73]
# increasing [18, 21, 24, 25, 27, 29]
# decreasing [73, 70, 68, 65, 62, 59, 58, 56]
# decreasing [68, 65, 62, 60, 59, 57, 54, 52]
# decreasing [11, 8, 6, 3, 2]
# increasing [28, 29, 31, 32, 34, 35, 36]
# increasing [37, 38, 41, 44, 46, 48, 49]
# increasing [60, 61, 64, 67, 70, 73, 75, 76]
# increasing [22, 23, 25, 28, 29]
# increasing [84, 87, 90, 92, 95, 96, 99]
# increasing [31, 33, 34, 35, 37, 40, 41, 42]
# decreasing [70, 68, 67, 65, 63]
# increasing [82, 84, 87, 88, 90, 92, 94, 95]
# increasing [86, 88, 89, 92, 94]
# decreasing [72, 69, 68, 67, 65, 64, 63]
# increasing [79, 82, 85, 86, 87, 90]
# increasing [29, 30, 32, 33, 36, 37, 39]
# increasing [36, 38, 39, 42, 43, 45, 47, 50]
# decreasing [70, 67, 66, 63, 62, 60, 58, 55]
# increasing [25, 26, 27, 28, 31, 34]
# decreasing [82, 80, 77, 75, 74, 73, 72, 70]
# increasing [3, 6, 8, 11, 12, 15]
# increasing [29, 30, 33, 35, 38, 41, 42, 43]
# increasing [44, 45, 48, 49, 52, 55, 57]
# increasing [47, 49, 51, 53, 56, 58]
# decreasing [60, 59, 57, 55, 52]
# increasing [22, 25, 28, 29, 31, 33]
# decreasing [22, 21, 19, 16, 14, 13]
# increasing [19, 21, 24, 26, 29, 32, 34, 37]
# decreasing [49, 46, 43, 42, 40, 37, 34]
# decreasing [40, 37, 35, 33, 31, 29, 27, 25]
# decreasing [84, 82, 80, 77, 74, 71, 70]
# decreasing [75, 73, 70, 67, 64, 61, 59]
# decreasing [55, 52, 51, 49, 48]
# increasing [71, 74, 76, 77, 79, 81]
# increasing [57, 59, 61, 63, 64, 67, 70]
# decreasing [55, 54, 53, 52, 50, 49, 46, 45]
# increasing [44, 47, 49, 51, 52, 53, 55, 57]
# increasing [84, 87, 88, 91, 94]
# decreasing [79, 77, 76, 73, 70, 67, 65, 64]
# decreasing [48, 47, 44, 42, 39, 38, 36, 35]
# decreasing [38, 36, 35, 34, 32, 29, 27, 26]
# increasing [58, 61, 64, 67, 70]
# increasing [83, 85, 87, 89, 90, 91, 93]
# decreasing [70, 69, 68, 66, 64, 62, 60, 58]
# decreasing [25, 22, 20, 17, 16]
# increasing [59, 62, 64, 67, 70, 73, 74]
# decreasing [56, 55, 54, 51, 50]
# increasing [36, 37, 38, 41, 43, 44, 47]
# decreasing [48, 46, 45, 42, 41, 40, 37]
# decreasing [41, 40, 39, 37, 35, 33, 31, 29]
# decreasing [52, 49, 46, 44, 43, 42]
# increasing [72, 73, 75, 76, 78, 79, 81, 84]
# increasing [75, 77, 80, 81, 84, 87, 88, 90]
# increasing [28, 29, 31, 32, 34, 37]
# increasing [20, 22, 24, 27, 28, 31, 33, 34]
# decreasing [39, 37, 34, 31, 29, 26, 23, 20]
# increasing [15, 16, 18, 19, 21, 24]
# increasing [36, 38, 40, 41, 44, 47, 48, 49]
# increasing [10, 12, 14, 17, 18, 19, 22]
# decreasing [27, 24, 23, 22, 19]
# decreasing [90, 87, 86, 85, 82, 79, 76]
# increasing [34, 35, 36, 37, 40, 42, 45]
# decreasing [66, 64, 62, 59, 56, 55, 54]
# increasing [60, 62, 64, 65, 66, 67, 70]
# increasing [37, 38, 40, 41, 42, 43]
# decreasing [79, 78, 77, 74, 73, 70, 68, 65]
# decreasing [22, 21, 19, 18, 15]
# decreasing [95, 94, 93, 92, 89, 88]
# decreasing [75, 72, 69, 66, 65]
# decreasing [25, 22, 19, 16, 14, 13, 12, 9]
# increasing [30, 31, 32, 33, 35]
# increasing [5, 6, 7, 9, 10, 13, 14, 17]
# increasing [82, 83, 85, 87, 89, 92, 93, 94]
# decreasing [54, 52, 51, 48, 46, 45]
# decreasing [35, 32, 29, 28, 27, 25, 23, 20]
# decreasing [51, 49, 46, 43, 42, 40]
# decreasing [39, 38, 35, 32, 30, 27]
# decreasing [48, 45, 42, 40, 38, 37, 35]
# decreasing [59, 58, 56, 53, 51, 48, 45]
# decreasing [76, 75, 73, 70, 68, 66, 63]
# increasing [68, 71, 74, 77, 80, 81, 82]
# increasing [28, 29, 31, 34, 35]
# increasing [88, 90, 91, 92, 94, 95, 98, 99]
# decreasing [69, 68, 65, 64, 62]
# decreasing [88, 86, 83, 81, 80]
# increasing [85, 88, 89, 92, 93, 94, 96]
# decreasing [38, 36, 34, 33, 30, 27, 26, 25]
# increasing [69, 70, 71, 73, 74, 77]
# increasing [22, 24, 27, 29, 32, 33, 35]
# increasing [80, 81, 83, 85, 87, 89, 91, 92]
# increasing [47, 49, 51, 53, 54, 56, 58]
# decreasing [45, 44, 41, 38, 36, 33, 30]
# increasing [16, 18, 19, 21, 24, 25, 26, 29]
# increasing [69, 70, 73, 76, 77, 80, 82]
# decreasing [86, 85, 83, 82, 80, 77]
# increasing [7, 8, 10, 11, 12, 13]
# decreasing [68, 65, 62, 60, 57]
# decreasing [20, 17, 16, 14, 13, 12]
# decreasing [90, 87, 86, 85, 83, 82, 80, 79]
# decreasing [20, 18, 16, 14, 13, 10]
# increasing [36, 38, 41, 44, 47, 48]
# increasing [64, 66, 69, 70, 72]
# decreasing [94, 91, 88, 85, 83, 80]
# increasing [25, 26, 29, 32, 33, 36]
# decreasing [26, 24, 21, 18, 17]
# decreasing [63, 60, 59, 56, 54]
# decreasing [40, 39, 38, 35, 32, 30]
# increasing [60, 63, 65, 67, 69, 71, 72]
# decreasing [16, 15, 12, 10, 9]
# increasing [49, 51, 54, 57, 58, 59, 62]
# increasing [48, 49, 52, 54, 55, 58, 61]
# decreasing [36, 35, 32, 31, 29]
# decreasing [73, 70, 69, 66, 63, 61, 59]
# increasing [16, 18, 19, 22, 25]
# decreasing [32, 30, 28, 26, 25, 22, 20]
# increasing [39, 42, 45, 48, 51, 54]
# increasing [70, 72, 73, 74, 76, 79, 80, 81]
# decreasing [37, 34, 31, 30, 29]
# increasing [15, 16, 17, 19, 21, 24]
# decreasing [31, 30, 28, 25, 23, 20, 18, 17]
# increasing [81, 82, 83, 86, 89, 91, 92, 94]
# decreasing [78, 76, 74, 72, 71]
# increasing [24, 25, 28, 30, 31, 32]
# decreasing [80, 79, 76, 75, 73, 72, 71]
# increasing [71, 72, 74, 76, 78, 81, 84, 86]
# increasing [8, 11, 14, 15, 18]
# decreasing [46, 43, 42, 41, 38, 35, 34]
# decreasing [20, 18, 17, 15, 14]
# decreasing [84, 82, 80, 79, 77, 76]
# increasing [43, 44, 47, 48, 50]
# 306

# %%
structure = []
for i in range(6):
    structure.append([int(i) for i in input().split()])
# Out:
#  a
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 3
#       1 structure = []
#       2 for i in range(6):
# ----> 3     structure.append([int(i) for i in input().split()])
#
# Cell In[3], line 3, in <listcomp>(.0)
#       1 structure = []
#       2 for i in range(6):
# ----> 3     structure.append([int(i) for i in input().split()])
#
# ValueError: invalid literal for int() with base 10: 'a'

# %%
ans = 0 
for temp in structure:
    # temp = [int(i) for i in line.split()]
    init_diff = temp[1] - temp[0]
    # print(f" initial diffence = {init_diff}")
    incr = True
    decr = True
    if init_diff > 0 and init_diff < 4: 
        #increasing
        for i in range(1, len(temp)-1):
            #print(f" Increasing branch - Val at i is: {temp[i+1]} and at i+1 is:{temp[i]} and  diff is: {temp[i+1]-temp[i]} something here")
            if temp[i+1]-temp[i] > 3 or temp[i+1]-temp[i] <= 0:
                incr = False
        if incr == True:
            print(f"increasing {temp}")
            ans += 1
        # print("Safe increasing")
    elif init_diff < 0 and init_diff > -4:
        #decreasing
        for i in range(1, len(temp)-1):
            #print(f" Decreasing branch - Val at i is: {temp[i]} and at i+1 is:{temp[i+1]} and  diff is: {temp[i]-temp[i+1]} something here")
            if temp[i]-temp[i+1] > 3 or temp[i]-temp[i+1] <= 0:
                decr = False
        # print("Safe decreasing")
        if decr == True:
            print(f"decreasing {temp}")
            ans += 1
    else:
        if init_diff >=1 and init_diff <= 3:
            print(init_diff)
        # print("Nope")
        # print(temp)
print(ans)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 ans = 0
# ----> 2 for temp in structure:
#       3     # temp = [int(i) for i in line.split()]
#       4     init_diff = temp[1] - temp[0]
#       5     # print(f" initial diffence = {init_diff}")
#
# NameError: name 'structure' is not defined
